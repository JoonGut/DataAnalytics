# %%
import pandas as pd

# %%
df_results = pd.read_csv("estadisticas.csv")

df_results.head()
print(df_results)
# Out:
#          Country  Population Aged 0 to 14 (%)  \
# 0    Afghanistan                         42.9
# 1        Albania                         16.8
# 2        Algeria                         30.3
# 3        Andorra                         11.9
# 4         Angola                         44.4
# ..           ...                          ...
# 187    Venezuela                         25.5
# 188      Vietnam                         23.2
# 189        Yemen                         41.1
# 190       Zambia                         41.5
# 191     Zimbabwe                         40.9
#
#      Population Aged 60 and Over (%)  Population density  \
# 0                                3.9                65.7
# 1                               23.5               101.9
# 2                               10.0                19.7
# 3                               23.2               174.3
# 4                                4.6                30.4
# ..                               ...                 ...
# ...

# %%
df_results.head()
# Out:
#        Country  Population Aged 0 to 14 (%)  Population Aged 60 and Over (%)  \
# 0  Afghanistan                         42.9                              3.9
# 1      Albania                         16.8                             23.5
# 2      Algeria                         30.3                             10.0
# 3      Andorra                         11.9                             23.2
# 4       Angola                         44.4                              4.6
#
#    Population density  Population(in millions)  \
# 0                65.7                    42.65
# 1               101.9                     2.79
# 2                19.7                    46.81
# 3               174.3                     0.08
# 4                30.4                    37.89
#
#    Female Population(in millions)  Male Population(in millions)  \
# 0                           21.12                         21.53
# 1                            1.41                          1.38
# ...

# %%
df_results.tail()
# Out:
#        Country  Population Aged 0 to 14 (%)  Population Aged 60 and Over (%)  \
# 187  Venezuela                         25.5                             14.3
# 188    Vietnam                         23.2                             13.9
# 189      Yemen                         41.1                              4.0
# 190     Zambia                         41.5                              3.3
# 191   Zimbabwe                         40.9                              5.0
#
#      Population density  Population(in millions)  \
# 187                31.0                    28.41
# 188               322.2                   100.99
# 189                76.9                    40.58
# 190                28.7                    21.32
# 191                43.0                    16.63
#
#      Female Population(in millions)  Male Population(in millions)  \
# 187                           14.37                         14.03
# 188                           51.53                         49.46
# ...

# %%
df_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country                            192 non-null    object
#  1   Population Aged 0 to 14 (%)        192 non-null    float64
#  2   Population Aged 60 and Over (%)    192 non-null    float64
#  3   Population density                 192 non-null    float64
#  4   Population(in millions)            192 non-null    float64
#  5   Female Population(in millions)     192 non-null    float64
#  6   Male Population(in millions)       192 non-null    float64
#  7   Sex ratio (males per 100 females)  192 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 12.1+ KB

# %%
df_results.describe()
# Out:
#        Population Aged 0 to 14 (%)  Population Aged 60 and Over (%)  \
# count                   192.000000                       192.000000
# mean                     26.308333                        14.167188
# std                      10.328998                         9.106158
# min                      10.600000                         3.300000
# 25%                      17.000000                         6.100000
# 50%                      24.650000                        11.250000
# 75%                      36.350000                        22.250000
# max                      49.000000                        43.500000
#
#        Population density  Population(in millions)  \
# count          192.000000               192.000000
# mean           348.131771                42.267812
# std           1969.940293               151.787795
# min              2.200000                 0.010000
# 25%             36.550000                 2.180000
# ...

# %%
df_results[['Country', 'Female Population(in millions)']]
# Out:
#          Country  Female Population(in millions)
# 0    Afghanistan                           21.12
# 1        Albania                            1.41
# 2        Algeria                           22.94
# 3        Andorra                            0.04
# 4         Angola                           19.14
# ..           ...                             ...
# 187    Venezuela                           14.37
# 188      Vietnam                           51.53
# 189        Yemen                           20.03
# 190       Zambia                           10.76
# 191     Zimbabwe                            8.71
#
# [192 rows x 2 columns]

# %%
df_results[df_results['Country'] == 'Tuvalu']
# Out:
#     Country  Population Aged 0 to 14 (%)  Population Aged 60 and Over (%)  \
# 176  Tuvalu                         32.9                             11.1
#
#      Population density  Population(in millions)  \
# 176               321.5                     0.01
#
#      Female Population(in millions)  Male Population(in millions)  \
# 176                             0.0                           0.0
#
#      Sex ratio (males per 100 females)
# 176                              104.8

# %%
df_results[(df_results['Female Population(in millions)'] < 0.05) & (df_results['Sex ratio (males per 100 females)']<92)]
# Out:
#                    Country  Population Aged 0 to 14 (%)  \
# 143  Saint Kitts and Nevis                         18.2
#
#      Population Aged 60 and Over (%)  Population density  \
# 143                             17.1               180.2
#
#      Population(in millions)  Female Population(in millions)  \
# 143                     0.05                            0.02
#
#      Male Population(in millions)  Sex ratio (males per 100 females)
# 143                          0.02                               91.8

# %%
df_results['Population Aged 60 and Over (%)'].max()

#df_results.groupby('Country')['Population Aged 60 and Over (%)'].mean()
# Out:
# Country
# Afghanistan     3.9
# Albania        23.5
# Algeria        10.0
# Andorra        23.2
# Angola          4.6
#                ...
# Venezuela      14.3
# Vietnam        13.9
# Yemen           4.0
# Zambia          3.3
# Zimbabwe        5.0
# Name: Population Aged 60 and Over (%), Length: 192, dtype: float64

# %%
df_results['Poblacion entre 0 y 14 (en millones)'] = df_results['Population(in millions)'] * df_results['Population Aged 0 to 14 (%)'] /100
df_results.head()
# Out:
#        Country  Population Aged 0 to 14 (%)  Population Aged 60 and Over (%)  \
# 0  Afghanistan                         42.9                              3.9
# 1      Albania                         16.8                             23.5
# 2      Algeria                         30.3                             10.0
# 3      Andorra                         11.9                             23.2
# 4       Angola                         44.4                              4.6
#
#    Population density  Population(in millions)  \
# 0                65.7                    42.65
# 1               101.9                     2.79
# 2                19.7                    46.81
# 3               174.3                     0.08
# 4                30.4                    37.89
#
#    Female Population(in millions)  Male Population(in millions)  \
# 0                           21.12                         21.53
# 1                            1.41                          1.38
# ...

# %%
df_results['Si tiene mas mujeres'] = df_results['Female Population(in millions)'] > df_results['Male Population(in millions)']
df_results.head()
# Out:
#        Country  Population Aged 0 to 14 (%)  Population Aged 60 and Over (%)  \
# 0  Afghanistan                         42.9                              3.9
# 1      Albania                         16.8                             23.5
# 2      Algeria                         30.3                             10.0
# 3      Andorra                         11.9                             23.2
# 4       Angola                         44.4                              4.6
#
#    Population density  Population(in millions)  \
# 0                65.7                    42.65
# 1               101.9                     2.79
# 2                19.7                    46.81
# 3               174.3                     0.08
# 4                30.4                    37.89
#
#    Female Population(in millions)  Male Population(in millions)  \
# 0                           21.12                         21.53
# 1                            1.41                          1.38
# ...

# %%
df_ine = pd.read_csv("ineGastoAutonomia.csv", sep=";", encoding='latin-1')

# %%
df_ine.head()
# Out:
#   Comunidades y Ciudades Autónomas de destino País de residencia Periodo  \
# 0                                   Andalucía              Total  2025T2
# 1                                   Andalucía              Total  2025T1
# 2                                   Andalucía              Total  2024T4
# 3                                   Andalucía              Total  2024T3
# 4                                   Andalucía              Total  2024T2
#
#     Total
# 0  443,24
# 1  500,83
# 2  451,81
# 3  483,88
# 4  433,29

# %%
df_ine['País de residencia'].value_counts()
# Out:
# País de residencia
# Total                        570
# Alemania                     570
# Andorra                      570
# Austria                      570
# Bélgica                      570
# Dinamarca                    570
# Finlandia                    570
# Francia                      570
# Irlanda                      570
# Italia                       570
# Noruega                      570
# Países Bajos                 570
# Polonia                      570
# Portugal                     570
# Reino Unido                  570
# Rumanía                      570
# Rusia                        570
# Suecia                       570
# Suiza                        570
# Otros Países Europeos        570
# Argentina                    570
# Brasil                       570
# Canadá                       570
# Chile                        570
# Colombia                     570
# Estados Unidos de América    570
# México                       570
# ...

# %%
df_ine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19950 entries, 0 to 19949
# Data columns (total 4 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Comunidades y Ciudades Autónomas de destino  19950 non-null  object
#  1   País de residencia                           19950 non-null  object
#  2   Periodo                                      19950 non-null  object
#  3   Total                                        19950 non-null  object
# dtypes: object(4)
# memory usage: 623.6+ KB

# %%
df_ine.describe()
# Out:
#        Comunidades y Ciudades Autónomas de destino País de residencia Periodo  \
# count                                        19950              19950   19950
# unique                                          19                 35      30
# top                                      Andalucía              Total  2025T2
# freq                                          1050                570     665
#
#         Total
# count   19950
# unique  14987
# top         .
# freq     3209

# %%
df_ine['Comunidades y Ciudades Autónomas de destino'].value_counts()
# Out:
# Comunidades y Ciudades Autónomas de destino
# Andalucía                      1050
# Aragón                         1050
# Asturias, Principado de        1050
# Balears, Illes                 1050
# Canarias                       1050
# Cantabria                      1050
# Castilla y León                1050
# Castilla - La Mancha           1050
# Cataluña                       1050
# Comunitat Valenciana           1050
# Extremadura                    1050
# Galicia                        1050
# Madrid, Comunidad de           1050
# Murcia, Región de              1050
# Navarra, Comunidad Foral de    1050
# País Vasco                     1050
# Rioja, La                      1050
# Ceuta                          1050
# Melilla                        1050
# Name: count, dtype: int64

# %%
df_euskadi = df_ine[df_ine['Comunidades y Ciudades Autónomas de destino']=='País Vasco']
df_euskadi.head()
# Out:
#       Comunidades y Ciudades Autónomas de destino País de residencia Periodo  \
# 15750                                  País Vasco              Total  2025T2
# 15751                                  País Vasco              Total  2025T1
# 15752                                  País Vasco              Total  2024T4
# 15753                                  País Vasco              Total  2024T3
# 15754                                  País Vasco              Total  2024T2
#
#         Total
# 15750  194,20
# 15751  175,37
# 15752  184,51
# 15753  162,84
# 15754  192,08

# %%
df_euskadi['Comunidades y Ciudades Autónomas de destino'].value_counts()
# Out:
# Comunidades y Ciudades Autónomas de destino
# País Vasco    1050
# Name: count, dtype: int64
